# %% [markdown]
# Please refer [sentdex](https://www.youtube.com/watch?v=Z78zbnLlPUA&list=PLQVvvaa0QuDdttJXlLtAJxJetJcqmqlQq)

# %% [markdown]
# ## Image read and show

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('elephant.jpg', cv2.IMREAD_UNCHANGED)  #IMREAD_GRAYSCALE or 0 #IMREAD_COLOR or 1; IMREAD_UNCHANGED or -1

#draw a line, on img, start point and end point and color and width
cv2.line(img, (0,400),(1000, 400), (255,255,255), 10)
#draw a rectangle
cv2.rectangle(img, (240, 20), (640, 400), (0, 0, 255), 5)
# draw a circle
cv2.circle(img, (700, 100), 50, (255, 0, 0), -1)
# draw  polylines
pts = np.array([[50,0], [20,10], [30,100], [70,30]], np.int32)
cv2.polylines(img, [pts], True, (0,255,255), 2)

# write text
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 'Giant King', (270,450), font, 2, (0,255,50), 2,cv2.LINE_AA)

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.show()

# %%
cv2.imwrite('elegray.png', img)
# Out:
# True

# %% [markdown]
# ## Video

# %%
import cv2
import numpy as np

# %% [markdown]
# ```python
# cap = cv2.VideoCapture(0)
#
# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))
# while True:
#
#     ret, frame = cap.read()
#     #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
#     cv2.imshow('frame', frame)
#     #cv2.imshow('gray', gray)
#
#     if cv2.waitkey(1) & 0XFF == ord('q'):
#         break
# cap.release()
# out.release()
# cv2.destroyAllWindows()
# ```

# %% [markdown]
# ## Basic image operation

# %%
img = cv2.imread('elephant.jpg', cv2.IMREAD_COLOR) 
print(img.shape)
# image pixel
px = img[300,200]
print(px)
img[50,50] = [255,255,255]
print(px)
# Out:
# (500, 1000, 3)
# [40 36 41]
# [40 36 41]

# %%
# region of image (ROI)

roi = img[0:100, 0:100]
print(roi)
cv2.imshow('roi', roi)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[141 150 163]
#   [141 150 163]
#   [141 150 163]
#   ...,
#   [129 141 147]
#   [128 140 146]
#   [128 140 146]]
#
#  [[141 150 163]
#   [141 150 163]
#   [141 150 163]
#   ...,
#   [129 141 147]
#   [129 141 147]
#   [128 140 146]]
#
#  [[141 150 163]
#   [141 150 163]
#   [141 150 163]
#   ...,
#   [129 141 147]
#   [129 141 147]
#   [128 140 146]]
#
#  ...,
#  [[111 123 129]
#   [111 123 129]
#   [111 123 129]
#   ...,
#   [147 157 167]
#   [148 158 168]
#   [148 158 168]]
#
#  [[111 123 129]
#   [111 123 129]
#   [111 123 129]
#   ...,
#   [147 157 167]
#   [147 157 167]
#   [147 157 167]]
#
#  [[111 123 129]
#   [111 123 129]
#   [111 123 129]
#   ...,
#   [147 157 167]
#   [148 158 168]
#   [148 158 168]]]

# %%
img[0:100, 0:100] = [255,255,255]

# you will see a white square in the upper left corner
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# copy region
ele_head = img[40:400, 260:640]
img[140:500,620:1000] = ele_head
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## image arithmetics and logic operations

# %%
img1 = cv2.imread('elephant.jpg') 
img2 = cv2.imread('colorado.jpg')

# %%
cv2.imshow('img1', img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('img2', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
weighted = cv2.addWeighted(img1, 0.4, img2, 0.6, 0)  # 0 is alpha

cv2.imshow('weighted', weighted )
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### threshold

# %%
taiji = cv2.imread('taiji.jpg')
cv2.imshow('taiji', taiji)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bagua = cv2.imread('bagua.jpg')
cv2.imshow('bagua', bagua)
cv2.waitKey(0)
cv2.destroyAllWindows()
