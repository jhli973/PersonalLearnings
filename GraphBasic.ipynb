# %%
import networkx as nx
# %matplotlib notebook

# %% [markdown]
# G = nx.Graph()
# G.add_edge(1,2)

# %%
G = nx.Graph()
e=[('a','b',0.3),('b','c',0.9),('a','c',0.5),('c','d',1.2)]
G.add_weighted_edges_from(e)

# %%
nx.draw(G)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# 5 ** 3

# %%
(1/3) ** 2 * (2/3) ** 3 *10
# Out:
# 0.32921810699588466

# %%
def fibonacci(n):
    
    fib_lst = []
    x = 0
    fib = 0
    
    while len(fib_lst) < n:
        
        if x == 0:
            fib = 0
        elif x == 1:
            fib = 1
        else:
            fib += x
        x += 1
        fib_lst.append(fib)
    return fib_lst

# %%
def fibonacci(x):
    
    if x == 0:
        fib1 = 0
    elif x == 1:
        fib1 = 1
    else:
        fib += x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2bd01767c270> in <module>()
# ----> 1 fibonacci(5)
#
# <ipython-input-21-3fedd8840e3c> in fibonacci(n)
#      16         x += 1
#      17     #return fib_lst
# ---> 18     return list(map(cube, fib_lst.append(fib)))
#      19
#
# NameError: name 'cube' is not defined

# %%
def fibR(n):
    if n==1:
        return 0
    if n==2:
        return 1
    return fibR(n-1)+fibR(n-2)
lst = []
for i in range(1, 7):
    lst.append(fibR(i))

# %%
print(lst)
# Out:
# [0, 1, 1, 2, 3, 5]

# %%
cube = lambda x: x ** 3

def fib(x):
    if x==1:
        return 0
    if x == 2:
        return 1
    return fib(x-1) + fib(x-2)

def fibonacci(n):
    # return a list of fibonacci numbers
    fib_lst = []

    if n == 1:
        fib_lst.append(0)
    else:
        for i in range(1, n+1):
            fib_lst.append(fib(i))
    return fib_lst

# %%
fibonacci(5)
# Out:
# [0, 1, 1, 2, 3]

# %%
print(list(map(cube,fibonacci(5))))
# Out:
# [0, 1, 1, 8, 27]
